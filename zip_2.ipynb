# %%
import os
import zipfile

root_dir = "/home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4"
target_rel_path = os.path.join("coarse", "scene.blend")  # relative path to match

for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        file_path = os.path.join(dirpath, filename)
        rel_path = os.path.relpath(file_path, root_dir)

        # Match only the specific file path
        if rel_path.endswith(target_rel_path):
            print("Target relative path found")
            processed_json = os.path.join(dirpath, "../visible_objects.json")
            processed_1_json = os.path.join(dirpath, "../cameras.json")

            if os.path.exists(processed_json):    
                print("Processed json found")
                zip_path = file_path + ".zip"
                print(rel_path)

                orig_size = os.path.getsize(file_path)
                print(f"Original size: {orig_size} bytes")

                # Create a zip file and add the .blend file
                with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED, compresslevel=1) as zipf:
                    zipf.write(file_path, arcname=os.path.basename(file_path))

                zip_size = os.path.getsize(zip_path)
                print(f"Zipped size: {zip_size} bytes")

                # Delete the original .blend file
                os.remove(file_path)
                print(f"Zipped and removed: {file_path}")
            else:
                print(f"Skipping {file_path} (no processed.json found)")
# Out:
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/2bed14bb/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/765b7b81/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/19ba0882/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/63fbca86/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/419a8500/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/706a135c/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/17a0c925/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/49d927/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/33f7efda/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/34944dbf/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/4df3f846/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/7d95b8a4/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/26cf8578/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/65375cf1/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/1199fa2d/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/6a7c7f53/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/76fc55f9/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/59c6d53a/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/6042a1e8/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/2aad3c3e/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/52cfb6a7/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/5f6082ce/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/4c9b8960/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/3eb01cf5/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/3bf882b9/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/4ef538ac/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/1b09c34a/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/5d717918/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/7d3b370/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/5938be25/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/2c6d08d4/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/11e4b899/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/DiningRoom_v6001_AA_Final_Part4/492b4b45/coarse/scene.blend (no processed.json found)
