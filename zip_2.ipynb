# %%
import os
import zipfile

root_dir = "/home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1"
target_rel_path = os.path.join("coarse", "scene.blend")  # relative path to match

for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        file_path = os.path.join(dirpath, filename)
        rel_path = os.path.relpath(file_path, root_dir)

        # Match only the specific file path
        if rel_path.endswith(target_rel_path):
            print("Target relative path found")
            processed_json = os.path.join(dirpath, "../visible_objects.json")
            processed_1_json = os.path.join(dirpath, "../cameras.json")

            if os.path.exists(processed_json):    
                print("Processed json found")
                zip_path = file_path + ".zip"
                print(rel_path)

                orig_size = os.path.getsize(file_path)
                print(f"Original size: {orig_size} bytes")

                # Create a zip file and add the .blend file
                with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED, compresslevel=1) as zipf:
                    zipf.write(file_path, arcname=os.path.basename(file_path))

                zip_size = os.path.getsize(zip_path)
                print(f"Zipped size: {zip_size} bytes")

                # Delete the original .blend file
                os.remove(file_path)
                print(f"Zipped and removed: {file_path}")
            else:
                print(f"Skipping {file_path} (no processed.json found)")
# Out:
# Target relative path found
# Processed json found
# 1189495c/coarse/scene.blend
# Original size: 3004025216 bytes
# Zipped size: 953257205 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/1189495c/coarse/scene.blend
# Target relative path found
# Processed json found
# f3eda59/coarse/scene.blend
# Original size: 2884819957 bytes
# Zipped size: 855774293 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/f3eda59/coarse/scene.blend
# Target relative path found
# Processed json found
# 2146ea42/coarse/scene.blend
# Original size: 3996143970 bytes
# Zipped size: 1161691278 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/2146ea42/coarse/scene.blend
# Target relative path found
# Processed json found
# 6d1052b3/coarse/scene.blend
# Original size: 2244745381 bytes
# Zipped size: 652933569 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/6d1052b3/coarse/scene.blend
# Target relative path found
# Processed json found
# 70d0c16d/coarse/scene.blend
# Original size: 2508125575 bytes
# Zipped size: 783649722 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/70d0c16d/coarse/scene.blend
# Target relative path found
# Processed json found
# 4e53ed1d/coarse/scene.blend
# Original size: 2050582727 bytes
# Zipped size: 598577832 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/4e53ed1d/coarse/scene.blend
# Target relative path found
# Processed json found
# 5d36bb91/coarse/scene.blend
# Original size: 2362760708 bytes
# Zipped size: 724512325 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/5d36bb91/coarse/scene.blend
# Target relative path found
# Processed json found
# 7b85b76c/coarse/scene.blend
# Original size: 1646192520 bytes
# Zipped size: 498333848 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/7b85b76c/coarse/scene.blend
# Target relative path found
# Processed json found
# 37d00371/coarse/scene.blend
# Original size: 2321868705 bytes
# Zipped size: 776403583 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/37d00371/coarse/scene.blend
# Target relative path found
# Processed json found
# 30692502/coarse/scene.blend
# Original size: 2733450169 bytes
# Zipped size: 806840514 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/30692502/coarse/scene.blend
# Target relative path found
# Processed json found
# 37b600b6/coarse/scene.blend
# Original size: 3938575742 bytes
# Zipped size: 1219648551 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/37b600b6/coarse/scene.blend
# Target relative path found
# Processed json found
# 3c7338b3/coarse/scene.blend
# Original size: 1898603714 bytes
# Zipped size: 582736709 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/3c7338b3/coarse/scene.blend
# Target relative path found
# Processed json found
# 4c68d4a9/coarse/scene.blend
# Original size: 2323341226 bytes
# Zipped size: 661224907 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/4c68d4a9/coarse/scene.blend
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/5de7d5ef/coarse/scene.blend (no processed.json found)
# Target relative path found
# Processed json found
# 489dda17/coarse/scene.blend
# Original size: 3409463127 bytes
# Zipped size: 1070938583 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/489dda17/coarse/scene.blend
# Target relative path found
# Processed json found
# 765a8e2a/coarse/scene.blend
# Original size: 2655768315 bytes
# Zipped size: 823639116 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/765a8e2a/coarse/scene.blend
# Target relative path found
# Processed json found
# 3c7605d9/coarse/scene.blend
# Original size: 1398782534 bytes
# Zipped size: 377121285 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/3c7605d9/coarse/scene.blend
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/44d1a6a7/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/46ec260f/coarse/scene.blend (no processed.json found)
# Target relative path found
# Processed json found
# 6f81cd21/coarse/scene.blend
# Original size: 2168554965 bytes
# Zipped size: 624055482 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/6f81cd21/coarse/scene.blend
# Target relative path found
# Processed json found
# 4ca8f0ad/coarse/scene.blend
# Original size: 2861950612 bytes
# Zipped size: 870237180 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/4ca8f0ad/coarse/scene.blend
# Target relative path found
# Processed json found
# 3b543c3d/coarse/scene.blend
# Original size: 2237997099 bytes
# Zipped size: 685765146 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/3b543c3d/coarse/scene.blend
# Target relative path found
# Processed json found
# 5b7bd697/coarse/scene.blend
# Original size: 3358570955 bytes
# Zipped size: 1056959944 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/5b7bd697/coarse/scene.blend
# Target relative path found
# Processed json found
# 47bbae2/coarse/scene.blend
# Original size: 2457990733 bytes
# Zipped size: 746114599 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/47bbae2/coarse/scene.blend
# Target relative path found
# Processed json found
# 1d2055c4/coarse/scene.blend
# Original size: 3400118234 bytes
# Zipped size: 1024112635 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/1d2055c4/coarse/scene.blend
# Target relative path found
# Processed json found
# 702bc61b/coarse/scene.blend
# Original size: 2277397832 bytes
# Zipped size: 661431349 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/702bc61b/coarse/scene.blend
# Target relative path found
# Processed json found
# 391016af/coarse/scene.blend
# Original size: 1623662122 bytes
# Zipped size: 478634919 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/391016af/coarse/scene.blend
# Target relative path found
# Processed json found
# 478cb37f/coarse/scene.blend
# Original size: 1402542395 bytes
# Zipped size: 434267144 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/478cb37f/coarse/scene.blend
# Target relative path found
# Processed json found
# 2b6717d2/coarse/scene.blend
# Original size: 2763753205 bytes
# Zipped size: 881111163 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/2b6717d2/coarse/scene.blend
# Target relative path found
# Processed json found
# 734d8d3e/coarse/scene.blend
# Original size: 2152181447 bytes
# Zipped size: 670138597 bytes
# Zipped and removed: /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/734d8d3e/coarse/scene.blend
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/Bedroom_v4001_Final_Part4_1/5dc49f79/coarse/scene.blend (no processed.json found)
