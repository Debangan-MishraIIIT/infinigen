# %%
import os
import zipfile

root_dir = "/home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4"
target_rel_path = os.path.join("coarse", "scene.blend")  # relative path to match

for dirpath, dirnames, filenames in os.walk(root_dir):
    for filename in filenames:
        file_path = os.path.join(dirpath, filename)
        rel_path = os.path.relpath(file_path, root_dir)

        # Match only the specific file path
        if rel_path.endswith(target_rel_path):
            print("Target relative path found")
            processed_json = os.path.join(dirpath, "../visible_objects.json")
            processed_1_json = os.path.join(dirpath, "../cameras.json")

            if os.path.exists(processed_json):    
                print("Processed json found")
                zip_path = file_path + ".zip"
                print(rel_path)

                orig_size = os.path.getsize(file_path)
                print(f"Original size: {orig_size} bytes")

                # Create a zip file and add the .blend file
                with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED, compresslevel=1) as zipf:
                    zipf.write(file_path, arcname=os.path.basename(file_path))

                zip_size = os.path.getsize(zip_path)
                print(f"Zipped size: {zip_size} bytes")

                # Delete the original .blend file
                os.remove(file_path)
                print(f"Zipped and removed: {file_path}")
            else:
                print(f"Skipping {file_path} (no processed.json found)")
# Out:
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/18b9cd77/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/6e8da443/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/20810fbc/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/6ce3292c/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/465a3461/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/48126f9d/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/7a036887/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/59e55d4f/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/3513941a/coarse/scene.blend (no processed.json found)
# Target relative path found
# Skipping /home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4/aae50d5/coarse/scene.blend (no processed.json found)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       4 root_dir = "/home/mila/a/ankur.sikarwar/scratch/infinigen/infinigen_debang/infinigen/v3001_final_outputs/LivingRoom_v6001_AA_Final_Part4"
#       5 target_rel_path = os.path.join("coarse", "scene.blend")  # relative path to match
# ----> 7 for dirpath, dirnames, filenames in os.walk(root_dir):
#       8     for filename in filenames:
#       9         file_path = os.path.join(dirpath, filename)
#
# File <frozen os>:419, in _walk(top, topdown, onerror, followlinks)
#
# File <frozen os>:419, in _walk(top, topdown, onerror, followlinks)
#
# File <frozen os>:419, in _walk(top, topdown, onerror, followlinks)
#
# File <frozen os>:358, in _walk(top, topdown, onerror, followlinks)
#
# KeyboardInterrupt:
